# %%
plot(sin(x)/x)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# -*- coding: utf-8 -*-

import numpy as np
from math import sin
import matplotlib.pyplot as plt

N = 41
K = 20
    
X = np.zeros((N,1))
Y_hat = np.zeros((N,1))
Y = np.zeros((N,1))

cpt = -20.0
for i in range(41):
    X[i,0] = cpt
    cpt += 1.0
for i in range(20):
    Y_hat[i,0] = sin(X[i,0])/X[i,0]
Y_hat[20,0] = 1.0 # Prolongement par continuité
for i in range(21,41,1):
    Y_hat[i,0] = sin(X[i,0])/X[i,0]
    
M = np.zeros((N,K))
for i in range(N):
    for j in range(K):
        M[i,j] = X[i,0]**j

A = np.matmul(np.transpose(M),M)
a = np.matmul(2*np.linalg.inv(A),np.matmul(np.transpose(M),Y_hat))
for i in range(N):
    somme = 0.0
    for j in range(K):
        somme += a[j,0]*(X[i,0]**j)
    Y[i,0] = somme
    somme = 0.0

x = list(X)
y = list(Y)
y_hat = list(Y_hat)
plt.plot(x,y)
plt.plot(x,y_hat)
plt.show()

# %%
var('t')
# Out:
# t

# %%
P = 0
for i in range(20):
    P += a[i]*t^i

# %%
P
# Out:
# array([(4.38505018602236e-25)*t^19 - (1.0774354052718455e-19)*t^18 - (7.9761433115972e-22)*t^17 + (2.0303254992955167e-16)*t^16 + (6.09412168236003e-19)*t^15 - (1.614887171507621e-13)*t^14 - (2.5403665462474976e-16)*t^13 + (7.042974198179802e-11)*t^12 + (6.278839719426367e-14)*t^11 - (1.829929579958215e-08)*t^10 - (9.358835947290278e-12)*t^9 + (2.8784042665486184e-06)*t^8 + (8.177133182074503e-10)*t^7 - 0.0002659315816231356*t^6 - (3.8627281253211274e-08)*t^5 + 0.013266155645055734*t^4 + (8.281130461078316e-07)*t^3 - 0.29843024959154724*t^2 - (5.202395356632124e-06)*t + 1.9402105045937788],
#       dtype=object)

# %%
a[0]
# Out:
# array([1.9402105])

# %%
len(a)
# Out:
# 20

# %%
Q = P[0]

# %%
Q
# Out:
# (4.38505018602236e-25)*t^19 - (1.0774354052718455e-19)*t^18 - (7.9761433115972e-22)*t^17 + (2.0303254992955167e-16)*t^16 + (6.09412168236003e-19)*t^15 - (1.614887171507621e-13)*t^14 - (2.5403665462474976e-16)*t^13 + (7.042974198179802e-11)*t^12 + (6.278839719426367e-14)*t^11 - (1.829929579958215e-08)*t^10 - (9.358835947290278e-12)*t^9 + (2.8784042665486184e-06)*t^8 + (8.177133182074503e-10)*t^7 - 0.0002659315816231356*t^6 - (3.8627281253211274e-08)*t^5 + 0.013266155645055734*t^4 + (8.281130461078316e-07)*t^3 - 0.29843024959154724*t^2 - (5.202395356632124e-06)*t + 1.9402105045937788

# %%
plot(Q)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
G = plot(Q, (t, -20, 20), thickness=5, color='green', title='A plot')

# %%
G
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
H = plt.plot(x,y_hat)

# %%
G + H
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-3784767b566d> in <module>
# ----> 1 G + H
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/graphics.py in __add__(self, other)
#    1194             if isinstance(other, Graphics3d):
#    1195                 return self.plot3d() + other
# -> 1196             raise TypeError("other (=%s) must be a Graphics objects"%other)
#    1197         g = Graphics()
#    1198         g._objects = self._objects + other._objects
#
# TypeError: other (=[<matplotlib.lines.Line2D object at 0x6ffe49465a90>]) must be a Graphics objects
