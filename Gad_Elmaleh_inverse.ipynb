# %%
import numpy as np
t = var('t')
v = var('v')
h = var('h')
t29 = var('t29')

# %%
v = 7/9
h = 4/47

# %%
t29 = (29 - 3840*v + 4200*h)/(v-h)

# %%
t29_double = np.double(t29)

# %%
g = Graphics()
g += plot((v-h)*t + 3840*v - 4200*h,t,t29_double -2 ,t29_double + 2)
g += plot(29.0,t,t29_double - 2,t29_double + 2)
g.show()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# <span style="color:red"> Conclusion: La baignoire n'atteindra jamais 29 litres. </span>

# %%
t29_double
# Out:
# -3753.901023890785

# %%
t29_double/60.0
# Out:
# -62.565017064846415
